# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64

# %%
import zipfile
with zipfile.ZipFile('test.zip', 'r') as zip_ref:
    zip_ref.extractall('test')
    
with zipfile.ZipFile('train.zip', 'r') as zip_ref:
    zip_ref.extractall('train')

# %%
path = os.path.abspath(os.getcwd())
path_img = path+'/train/train'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/notebooks/course-v3/nbs/HW/train/train/cat.0.jpg'),
#  PosixPath('/notebooks/course-v3/nbs/HW/train/train/cat.1.jpg'),
#  PosixPath('/notebooks/course-v3/nbs/HW/train/train/cat.10.jpg'),
#  PosixPath('/notebooks/course-v3/nbs/HW/train/train/cat.100.jpg'),
#  PosixPath('/notebooks/course-v3/nbs/HW/train/train/cat.1000.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)\.\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:04<00:00, 19.0MB/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.084660</td>
#       <td>0.048894</td>
#       <td>0.015400</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.060852</td>
#       <td>0.032236</td>
#       <td>0.011000</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.041216</td>
#       <td>0.027592</td>
#       <td>0.009200</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.030910</td>
#       <td>0.025625</td>
#       <td>0.008600</td>
#       <td>02:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
